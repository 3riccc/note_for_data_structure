// %% [markdown]
// # 十字链表
//
// **有向图的链式存储结构**
//
// - 邻接表是横着的
// - 逆邻接表是竖着的
// - 连在一起构成十字链表

// %% [markdown]
// ## 一图详解十字链表

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ## 数据结构定义
// - pass

// %% [markdown]
// ## 特点
// - 容易求出节点的入度和出度
// - 创建十字链表的时间复杂度和创建邻接表的时间复杂度相同
// - 一个十字链表确定一个图，但一个图可以对应多个十字链表（连边无序）
