// %% [markdown]
// # 选择题难题的记录

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 我tm忽然觉得，就这道题而言，妄图寻找普适规律是扯淡的
//
// 这是选择题啊
//
// 直接构造特殊情况
//
// 让前面的2011-116个节点每一个都是上一个的孩子
//
// 最后116个节点是最后的一个节点的孩子
//
// 一算就出来了

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// # 比较难的综合题

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ![image.png](attachment:image.png)
