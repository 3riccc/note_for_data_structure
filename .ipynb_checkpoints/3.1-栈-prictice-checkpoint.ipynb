// %% [markdown]
// # 知识点的判断

// %% [markdown]
// - 栈和队列的逻辑结构是相同的
//     - 都是线性结构
//     - 逻辑结构分为
//         - 线性结构：线性表，栈，队列
//         - 非线性结构：树，图，集合
//
// <hr/>
// - 这里有一道错题，体会这个过程
// ![image.png](attachment:image.png)
//
//
//
// <hr/>
// - 标识符：必须以大小写字母或者下划线开头，不能以数字开头

// %% [markdown]
// # 综合题

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ![image.png](attachment:image.png)

// %%
//4.

int  Judge_Symmetry(Linklist &L,int n){
    //创造一个数组---
    arr = int[n]
    //填充数组元素
    //重新走一半数组，判断是否中心对称
}

// 按照标准思路
int Judge_Symmetry(Linklist &L,int n){
    //创建储存结果的变量,1表示对称
    int res = 1;
    //创建一个栈
    int i;
    char s[n/2];
    
    //把链表前半段元素放进去
    while(i<n/2){
        s[i] = L->data;
        L = L->next;
        i ++ ;
    }
    
    //如果n是奇数，就跳过中间的元素
    if(n % 2 == 1){
        L = L->next;
    }
    
    //依次出栈，并比较
    while(i>=0){
        if(s[i] != L->data){
            res = 0;
        }
        i -- ;
        L = L->next;
    }
    return res;
}
//这个思路的确比我想的牛逼

// %%
//5
//先不做了
