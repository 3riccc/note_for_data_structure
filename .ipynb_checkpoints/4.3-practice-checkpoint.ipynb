// %% [markdown]
// # 4.3 practice

// %% [markdown]
// # 一些选择题

// %% [markdown]
// <hr/>

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// - n在m前面，可能性有三种
// ![image.png](attachment:image.png)

// %% [markdown]
// <hr/>

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// <hr/>

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// <hr/>

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ## 很难的大题

// %% [markdown]
// ![image.png](attachment:image.png)
