// %% [markdown]
// # 拓扑排序

// %% [markdown]
// ### 有向五环图
// - 就像标题一样理解
// - 简称DAG

// %% [markdown]
// ### AOV网
// - 如果用DAG表示一个工程
// - 顶点表示活动
// - 边<vi,vj>表示活动 i 必须先于活动 j

// %% [markdown]
// ### 拓扑排序（DAG中的顶点组成的序列）
// - 每个顶点只出现一次
// - 如果顶点A出现在B的前面，说明DAG中不存在从B到A的路径
//
// <hr/>
// #### 对拓扑排序的理解
// - 对节点的排序
// - 如果有从A到B的路径，那么B就出现在A的后面
// - 显然不唯一
// - 显然只适用于有向五环图

// %% [markdown]
// ## 关键路径
// ![image.png](attachment:image.png)
