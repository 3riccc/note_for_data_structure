// %% [markdown]
// # 分块查找
// 又称为索引顺序查找

// %% [markdown]
// - 吸取了顺序查找和折半查找各自的优点

// %% [markdown]
// ## 基本思想
// - 把查表分成若干个子块
// - 块内元素可以无序，但块间必须有序
// - 前一个块内所有关键字都小于后一个块的最小关键字
// - 建立一个索引表
//     - 各块最大关键字
//     - 各块中第一个元素地址
//     - 索引表有序排列
// <hr/>
// - 第一步在记录中查找所在的块（可以顺序或折半）
// - 第二部：块内顺序查找
// ![image.png](attachment:image.png)

// %% [markdown]
// <hr/>
// ## 平均查找长度
// ![image.png](attachment:image.png)
