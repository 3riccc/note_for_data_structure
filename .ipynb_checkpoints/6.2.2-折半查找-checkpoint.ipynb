// %% [markdown]
// # 折半查找
// - 又叫二分查找
// - 仅适用于有序顺序表

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// - 最多比较次数：树的高[log2N]+1
// - 适合线性存储，不适合链式存储
// -

// %% [markdown]
// ## 时间复杂度
// O(log2N)

// %% [markdown]
// ## 操作细节
// - 折半查找的判定树与树中节点的值无关，只与序号有关
// - 向上取整，（1+10）/2 = 6
// - 向下取整=5

// %% [markdown]
// **例：写出十个节点的折半查找树**
// ![image.png](attachment:image.png)
