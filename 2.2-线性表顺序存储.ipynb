// %% [markdown]
// # 线性表的顺序结构

// %% [markdown]
// ## 定义方法

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ## 做题中的实现方法
// ![image.png](attachment:image.png)

// %%
// 例如：申请一个10维数组，c中
q = (int *)malloc(sizeof(int)*10)
// c++中
int *q = new int[10]

//后面对数组中元素的访问
q[3] //访问第四个元素
